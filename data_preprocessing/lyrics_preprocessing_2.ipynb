# %% [markdown]
# # 1. 노래 전처리

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('all_plus.csv')
df.replace('\n', ' ')
df
# Out:
#                            _id       genre  \
# 0     6049e644b45c9405c3eed243         발라드
# 1     6049e644b45c9405c3eed244         발라드
# 2     6049e644b45c9405c3eed245   발라드, 인디음악
# 3     6049e644b45c9405c3eed246  발라드, 국내드라마
# 4     6049e644b45c9405c3eed247         발라드
# ...                        ...         ...
# 6995  604b35b474697bf97026f655        록/메탈
# 6996  604b35b474697bf97026f656  인디음악, 록/메탈
# 6997  604b35b474697bf97026f657  인디음악, 록/메탈
# 6998  604b35b474697bf97026f658  인디음악, 록/메탈
# 6999  604b35b474697bf97026f659  인디음악, 록/메탈
#
#                                                   lyric        singer  \
# 0     너는 많은 이름이 있어\n아픔 슬픔\n나는 너를 이렇게 불러\n기억 눈물\n수많은 ...           지동국
# 1     적당히 취한 온기에\n널 바래다주던 골목길\n헤어지기 싫어 아까워\n몇번이나 돌아보...    최도영(CANDO)
# 2     언제 변할지 모르는 너의\n마음을 두고 나는 다시 갇히네\nI don't wanna...            이제
# 3     thinking about the time\nthe world just got qu...          Jade
# 4     Time for Love 너만 보이는 시간\n소란했던 하루의 언덕 넘어\n마주하는 ...      정철 (최정철)
# ...                                                 ...           ...
# 6995                                               가사없음           준까치
# 6996  하늘의 창문 열려있고\n폭풍이 치네\n풀려난 영혼들 수많은 말들\n미칠 것 같아\n...        hanuva
# 6997  예감하던 이별이 다가와서\n슬퍼하는 표정이 드러나고\n가기전에 한번 안아달라던\n안...           신현재
# 6998  달아나지마요 조금 더 가까이\n이제 몸을 틀어 나를 바라봐줘요\n돌아보지마요 이미 ...            도하
# 6999  고운눈 온다 소금소금\n부지런한 사람들은 우리를 참지못해\n누가 깰세라 소근소근\n...  캡사이신스투키 2046
#
#                       title
# 0                  너의 많은 이름
# 1                니가 묻어있는 겨울
# 2        Show me your smile
# 3           I'll Come Alive
# 4                 너만 보이는 시간
# ...                     ...
# 6995                BERMUDA
# 6996  폭풍(Storm) (2020 ver.)
# 6997                  마지막으로
# 6998                    304
# 6999                   소금소금
#
# [7000 rows x 5 columns]

# %%
df.drop_duplicates(subset=['lyric'], inplace=True) # 중복 제거
df
# Out:
#                            _id       genre  \
# 0     6049e644b45c9405c3eed243         발라드
# 1     6049e644b45c9405c3eed244         발라드
# 2     6049e644b45c9405c3eed245   발라드, 인디음악
# 3     6049e644b45c9405c3eed246  발라드, 국내드라마
# 4     6049e644b45c9405c3eed247         발라드
# ...                        ...         ...
# 6994  604b35b474697bf97026f654  인디음악, 록/메탈
# 6996  604b35b474697bf97026f656  인디음악, 록/메탈
# 6997  604b35b474697bf97026f657  인디음악, 록/메탈
# 6998  604b35b474697bf97026f658  인디음악, 록/메탈
# 6999  604b35b474697bf97026f659  인디음악, 록/메탈
#
#                                                   lyric        singer  \
# 0     너는 많은 이름이 있어\n아픔 슬픔\n나는 너를 이렇게 불러\n기억 눈물\n수많은 ...           지동국
# 1     적당히 취한 온기에\n널 바래다주던 골목길\n헤어지기 싫어 아까워\n몇번이나 돌아보...    최도영(CANDO)
# 2     언제 변할지 모르는 너의\n마음을 두고 나는 다시 갇히네\nI don't wanna...            이제
# 3     thinking about the time\nthe world just got qu...          Jade
# 4     Time for Love 너만 보이는 시간\n소란했던 하루의 언덕 넘어\n마주하는 ...      정철 (최정철)
# ...                                                 ...           ...
# 6994  나와 보던 사라지고\n정지하던 바람길은\n그대로인 흐름들은\n끝내야 끝내고 싶고\n...         김씨아이씨
# 6996  하늘의 창문 열려있고\n폭풍이 치네\n풀려난 영혼들 수많은 말들\n미칠 것 같아\n...        hanuva
# 6997  예감하던 이별이 다가와서\n슬퍼하는 표정이 드러나고\n가기전에 한번 안아달라던\n안...           신현재
# 6998  달아나지마요 조금 더 가까이\n이제 몸을 틀어 나를 바라봐줘요\n돌아보지마요 이미 ...            도하
# 6999  고운눈 온다 소금소금\n부지런한 사람들은 우리를 참지못해\n누가 깰세라 소근소근\n...  캡사이신스투키 2046
#
#                       title
# 0                  너의 많은 이름
# 1                니가 묻어있는 겨울
# 2        Show me your smile
# 3           I'll Come Alive
# 4                 너만 보이는 시간
# ...                     ...
# 6994                  다랑쉬오름
# 6996  폭풍(Storm) (2020 ver.)
# 6997                  마지막으로
# 6998                    304
# 6999                   소금소금
#
# [5845 rows x 5 columns]

# %%
def delete_re_dm(dataframe,column):
    dataframe[column] = dataframe[column].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', " ")
    dataframe1 = dataframe.drop_duplicates(subset=[column], inplace=False)
    dataframe2 = dataframe1.dropna(how='any')
    dataframe2.reset_index(inplace=True)
    dataframe2.drop(columns = 'index', inplace=True)
    return dataframe2

def delete_dp_dm(dataframe,column):
    dataframe1 = dataframe.copy()
    dataframe1[column] = dataframe1[column].apply(lambda x : x.strip())
    dataframe1[dataframe1[column]==''] = np.nan
    dataframe2 = dataframe1.dropna(how='any')
    dataframe2.reset_index(inplace=True)
    dataframe2.drop(columns = 'index', inplace=True)
    return dataframe2

# %%
df = delete_re_dm(df, 'lyric')
df = delete_dp_dm(df, 'lyric')
df
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                            _id       genre  \
# 0     6049e644b45c9405c3eed243         발라드
# 1     6049e644b45c9405c3eed244         발라드
# 2     6049e644b45c9405c3eed245   발라드, 인디음악
# 3     6049e644b45c9405c3eed247         발라드
# 4     6049e644b45c9405c3eed248         발라드
# ...                        ...         ...
# 5426  604b35b474697bf97026f654  인디음악, 록/메탈
# 5427  604b35b474697bf97026f656  인디음악, 록/메탈
# 5428  604b35b474697bf97026f657  인디음악, 록/메탈
# 5429  604b35b474697bf97026f658  인디음악, 록/메탈
# 5430  604b35b474697bf97026f659  인디음악, 록/메탈
#
#                                                   lyric        singer  \
# 0     너는 많은 이름이 있어 아픔 슬픔 나는 너를 이렇게 불러 기억 눈물 수많은 너는 매...           지동국
# 1     적당히 취한 온기에 널 바래다주던 골목길 헤어지기 싫어 아까워 몇번이나 돌아보고 차...    최도영(CANDO)
# 2     언제 변할지 모르는 너의 마음을 두고 나는 다시 갇히네                ...            이제
# 3     너만 보이는 시간 소란했던 하루의 언덕 넘어 마주하는 너 일렁이는 저 하늘에 물든 ...      정철 (최정철)
# 4     너란 사람 나밖에 몰라서 다른 누굴 만날 수 있을까 우리 앞에 이별이 기다리잖아 되...            AJ
# ...                                                 ...           ...
# 5426  나와 보던 사라지고 정지하던 바람길은 그대로인 흐름들은 끝내야 끝내고 싶고 익숙한 ...         김씨아이씨
# 5427  하늘의 창문 열려있고 폭풍이 치네 풀려난 영혼들 수많은 말들 미칠 것 같아 여기 구...        hanuva
# 5428  예감하던 이별이 다가와서 슬퍼하는 표정이 드러나고 가기전에 한번 안아달라던 안겨있는...           신현재
# 5429  달아나지마요 조금 더 가까이 이제 몸을 틀어 나를 바라봐줘요 돌아보지마요 이미 떠났...            도하
# 5430  고운눈 온다 소금소금 부지런한 사람들은 우리를 참지못해 누가 깰세라 소근소근 긴 밤...  캡사이신스투키 2046
#
#                       title
# 0                  너의 많은 이름
# 1                니가 묻어있는 겨울
# 2        Show me your smile
# 3                 너만 보이는 시간
# 4      너란 사람 (Vocal by 주우빈)
# ...                     ...
# 5426                  다랑쉬오름
# 5427  폭풍(Storm) (2020 ver.)
# 5428                  마지막으로
# 5429                    304
# 5430                   소금소금
#
# [5431 rows x 5 columns]

# %%
df1 = df[df['lyric']=='가사없음'].index
df = df.drop(df1)
df # '가사없음' 1개
# Out:
#                            _id       genre  \
# 0     6049e644b45c9405c3eed243         발라드
# 1     6049e644b45c9405c3eed244         발라드
# 2     6049e644b45c9405c3eed245   발라드, 인디음악
# 3     6049e644b45c9405c3eed247         발라드
# 4     6049e644b45c9405c3eed248         발라드
# ...                        ...         ...
# 5426  604b35b474697bf97026f654  인디음악, 록/메탈
# 5427  604b35b474697bf97026f656  인디음악, 록/메탈
# 5428  604b35b474697bf97026f657  인디음악, 록/메탈
# 5429  604b35b474697bf97026f658  인디음악, 록/메탈
# 5430  604b35b474697bf97026f659  인디음악, 록/메탈
#
#                                                   lyric        singer  \
# 0     너는 많은 이름이 있어 아픔 슬픔 나는 너를 이렇게 불러 기억 눈물 수많은 너는 매...           지동국
# 1     적당히 취한 온기에 널 바래다주던 골목길 헤어지기 싫어 아까워 몇번이나 돌아보고 차...    최도영(CANDO)
# 2     언제 변할지 모르는 너의 마음을 두고 나는 다시 갇히네                ...            이제
# 3     너만 보이는 시간 소란했던 하루의 언덕 넘어 마주하는 너 일렁이는 저 하늘에 물든 ...      정철 (최정철)
# 4     너란 사람 나밖에 몰라서 다른 누굴 만날 수 있을까 우리 앞에 이별이 기다리잖아 되...            AJ
# ...                                                 ...           ...
# 5426  나와 보던 사라지고 정지하던 바람길은 그대로인 흐름들은 끝내야 끝내고 싶고 익숙한 ...         김씨아이씨
# 5427  하늘의 창문 열려있고 폭풍이 치네 풀려난 영혼들 수많은 말들 미칠 것 같아 여기 구...        hanuva
# 5428  예감하던 이별이 다가와서 슬퍼하는 표정이 드러나고 가기전에 한번 안아달라던 안겨있는...           신현재
# 5429  달아나지마요 조금 더 가까이 이제 몸을 틀어 나를 바라봐줘요 돌아보지마요 이미 떠났...            도하
# 5430  고운눈 온다 소금소금 부지런한 사람들은 우리를 참지못해 누가 깰세라 소근소근 긴 밤...  캡사이신스투키 2046
#
#                       title
# 0                  너의 많은 이름
# 1                니가 묻어있는 겨울
# 2        Show me your smile
# 3                 너만 보이는 시간
# 4      너란 사람 (Vocal by 주우빈)
# ...                     ...
# 5426                  다랑쉬오름
# 5427  폭풍(Storm) (2020 ver.)
# 5428                  마지막으로
# 5429                    304
# 5430                   소금소금
#
# [5430 rows x 5 columns]

# %%
df.to_csv('all_plus_clean.csv', index=False)

# %%
df = pd.read_csv('all_plus_clean.csv')
df
# Out:
#                            _id       genre  \
# 0     6049e644b45c9405c3eed243         발라드
# 1     6049e644b45c9405c3eed244         발라드
# 2     6049e644b45c9405c3eed245   발라드, 인디음악
# 3     6049e644b45c9405c3eed247         발라드
# 4     6049e644b45c9405c3eed248         발라드
# ...                        ...         ...
# 5425  604b35b474697bf97026f654  인디음악, 록/메탈
# 5426  604b35b474697bf97026f656  인디음악, 록/메탈
# 5427  604b35b474697bf97026f657  인디음악, 록/메탈
# 5428  604b35b474697bf97026f658  인디음악, 록/메탈
# 5429  604b35b474697bf97026f659  인디음악, 록/메탈
#
#                                                   lyric        singer  \
# 0     너는 많은 이름이 있어 아픔 슬픔 나는 너를 이렇게 불러 기억 눈물 수많은 너는 매...           지동국
# 1     적당히 취한 온기에 널 바래다주던 골목길 헤어지기 싫어 아까워 몇번이나 돌아보고 차...    최도영(CANDO)
# 2     언제 변할지 모르는 너의 마음을 두고 나는 다시 갇히네                ...            이제
# 3     너만 보이는 시간 소란했던 하루의 언덕 넘어 마주하는 너 일렁이는 저 하늘에 물든 ...      정철 (최정철)
# 4     너란 사람 나밖에 몰라서 다른 누굴 만날 수 있을까 우리 앞에 이별이 기다리잖아 되...            AJ
# ...                                                 ...           ...
# 5425  나와 보던 사라지고 정지하던 바람길은 그대로인 흐름들은 끝내야 끝내고 싶고 익숙한 ...         김씨아이씨
# 5426  하늘의 창문 열려있고 폭풍이 치네 풀려난 영혼들 수많은 말들 미칠 것 같아 여기 구...        hanuva
# 5427  예감하던 이별이 다가와서 슬퍼하는 표정이 드러나고 가기전에 한번 안아달라던 안겨있는...           신현재
# 5428  달아나지마요 조금 더 가까이 이제 몸을 틀어 나를 바라봐줘요 돌아보지마요 이미 떠났...            도하
# 5429  고운눈 온다 소금소금 부지런한 사람들은 우리를 참지못해 누가 깰세라 소근소근 긴 밤...  캡사이신스투키 2046
#
#                       title
# 0                  너의 많은 이름
# 1                니가 묻어있는 겨울
# 2        Show me your smile
# 3                 너만 보이는 시간
# 4      너란 사람 (Vocal by 주우빈)
# ...                     ...
# 5425                  다랑쉬오름
# 5426  폭풍(Storm) (2020 ver.)
# 5427                  마지막으로
# 5428                    304
# 5429                   소금소금
#
# [5430 rows x 5 columns]
