# %%
import pandas as pd
import numpy as np

df = pd.read_csv('all.csv')
df.replace('\n', ' ')
df
# Out:
#                            _id       genre              title singer  \
# 0     600fe17de8010db47d0367c1         발라드  이 소설의 끝을 다시 써보려 해    한동근
# 1     600fe17de8010db47d0367c2  발라드, 국내드라마           걱정말아요 그대     이적
# 2     600fe17de8010db47d0367c3         발라드            또 다시 사랑    임창정
# 3     600fe17de8010db47d0367c4         발라드       바람이 불었으면 좋겠어   길구봉구
# 4     600fe17de8010db47d0367c5  발라드, 국내드라마                 소녀     오혁
# ...                        ...         ...                ...    ...
# 4818  6010c41d24b299478c39062c        성인가요                가락지    황진희
# 4819  6010c41d24b299478c39062d        성인가요                잊으리    이승연
# 4820  6010c41d24b299478c39062e        성인가요           존재의 이유 Ⅱ    김종환
# 4821  6010c41d24b299478c39062f        성인가요             당신은 몰라     최헌
# 4822  6010c41d24b299478c390630        성인가요              백치아다다    문주란
#
#                                                   lyric
# 0     시계가 반대로 돌아가고 있어 TV속 영화가 되감아지고 있어 내렸던 빗물이 올라가고 ...
# 1     그대여 아무 걱정 하지 말아요 우리 함께 노래 합시다 그대 아픈 기억들 모두 그대여...
# 2     아픔이 좀 더 작아질까 의미 없는 만남을 하다가 어느 날 그대가 흘린 눈물 왠지 나...
# 3     웃는 모습이 너무 아름다운 그런 너를 기억하면서 괜찮아 넌 잘할거라 말하던 또 그런...
# 4     내 곁에만 머물러요 떠나면 안돼요 그리움 두고 머나먼 길 그대 무지개를 찾아올 순 ...
# ...                                                 ...
# 4818  당신이 주신 가락지 먼 길을 떠나는 당신 하염없는 눈물로 한 짝을 떼어 당신 손에 ...
# 4819                                               가사없음
# 4820  힘이 들 때면 너를 생각해 하루 중에 바쁜 시간도 널 위해 참는 거야 정말 미안해 ...
# 4821  여기에 당신의 모습이 보인다 가슴에 기대어 수줍던 그모습이 세월은 흘러서 당신은 떠...
# 4822  1. 초여름 산들바람 고운볼에스칠때 검은머리 금비녀에 다홍치마 어여뻐라 꽃가마에 미...
#
# [4823 rows x 5 columns]

# %%
df.drop_duplicates(subset=['lyric'], inplace=True) # 중복 제거
df
# Out:
#                            _id       genre              title singer  \
# 0     600fe17de8010db47d0367c1         발라드  이 소설의 끝을 다시 써보려 해    한동근
# 1     600fe17de8010db47d0367c2  발라드, 국내드라마           걱정말아요 그대     이적
# 2     600fe17de8010db47d0367c3         발라드            또 다시 사랑    임창정
# 3     600fe17de8010db47d0367c4         발라드       바람이 불었으면 좋겠어   길구봉구
# 4     600fe17de8010db47d0367c5  발라드, 국내드라마                 소녀     오혁
# ...                        ...         ...                ...    ...
# 4817  6010c41d24b299478c39062b        성인가요              울산아리랑    오은정
# 4818  6010c41d24b299478c39062c        성인가요                가락지    황진희
# 4820  6010c41d24b299478c39062e        성인가요           존재의 이유 Ⅱ    김종환
# 4821  6010c41d24b299478c39062f        성인가요             당신은 몰라     최헌
# 4822  6010c41d24b299478c390630        성인가요              백치아다다    문주란
#
#                                                   lyric
# 0     시계가 반대로 돌아가고 있어 TV속 영화가 되감아지고 있어 내렸던 빗물이 올라가고 ...
# 1     그대여 아무 걱정 하지 말아요 우리 함께 노래 합시다 그대 아픈 기억들 모두 그대여...
# 2     아픔이 좀 더 작아질까 의미 없는 만남을 하다가 어느 날 그대가 흘린 눈물 왠지 나...
# 3     웃는 모습이 너무 아름다운 그런 너를 기억하면서 괜찮아 넌 잘할거라 말하던 또 그런...
# 4     내 곁에만 머물러요 떠나면 안돼요 그리움 두고 머나먼 길 그대 무지개를 찾아올 순 ...
# ...                                                 ...
# 4817  운무를 품에 안고 사랑 찾는 무룡산아 산딸기 머루 다래 따다주던 그 손길 앵두같은 ...
# 4818  당신이 주신 가락지 먼 길을 떠나는 당신 하염없는 눈물로 한 짝을 떼어 당신 손에 ...
# 4820  힘이 들 때면 너를 생각해 하루 중에 바쁜 시간도 널 위해 참는 거야 정말 미안해 ...
# 4821  여기에 당신의 모습이 보인다 가슴에 기대어 수줍던 그모습이 세월은 흘러서 당신은 떠...
# 4822  1. 초여름 산들바람 고운볼에스칠때 검은머리 금비녀에 다홍치마 어여뻐라 꽃가마에 미...
#
# [4370 rows x 5 columns]

# %%
def delete_re_dm(dataframe,column):
    dataframe[column] = dataframe[column].str.replace('[^ㄱ-ㅎㅏ-ㅣ가-힣 ]', " ")
    dataframe1 = dataframe.drop_duplicates(subset=[column], inplace=False)
    dataframe2 = dataframe1.dropna(how='any')
    dataframe2.reset_index(inplace=True)
    dataframe2.drop(columns = 'index', inplace=True)
    return dataframe2

def delete_dp_dm(dataframe,column):
    dataframe1 = dataframe.copy()
    dataframe1[column] = dataframe1[column].apply(lambda x : x.strip())
    dataframe1[dataframe1[column]==''] = np.nan
    dataframe2 = dataframe1.dropna(how='any')
    dataframe2.reset_index(inplace=True)
    dataframe2.drop(columns = 'index', inplace=True)
    return dataframe2

# %%
df = delete_re_dm(df, 'lyric')
df = delete_dp_dm(df, 'lyric')
df
# Out:
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# C:\Users\user\anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                            _id       genre              title singer  \
# 0     600fe17de8010db47d0367c1         발라드  이 소설의 끝을 다시 써보려 해    한동근
# 1     600fe17de8010db47d0367c2  발라드, 국내드라마           걱정말아요 그대     이적
# 2     600fe17de8010db47d0367c3         발라드            또 다시 사랑    임창정
# 3     600fe17de8010db47d0367c4         발라드       바람이 불었으면 좋겠어   길구봉구
# 4     600fe17de8010db47d0367c5  발라드, 국내드라마                 소녀     오혁
# ...                        ...         ...                ...    ...
# 4319  6010c41d24b299478c39062b        성인가요              울산아리랑    오은정
# 4320  6010c41d24b299478c39062c        성인가요                가락지    황진희
# 4321  6010c41d24b299478c39062e        성인가요           존재의 이유 Ⅱ    김종환
# 4322  6010c41d24b299478c39062f        성인가요             당신은 몰라     최헌
# 4323  6010c41d24b299478c390630        성인가요              백치아다다    문주란
#
#                                                   lyric
# 0     시계가 반대로 돌아가고 있어   속 영화가 되감아지고 있어 내렸던 빗물이 올라가고 ...
# 1     그대여 아무 걱정 하지 말아요 우리 함께 노래 합시다 그대 아픈 기억들 모두 그대여...
# 2     아픔이 좀 더 작아질까 의미 없는 만남을 하다가 어느 날 그대가 흘린 눈물 왠지 나...
# 3     웃는 모습이 너무 아름다운 그런 너를 기억하면서 괜찮아 넌 잘할거라 말하던 또 그런...
# 4     내 곁에만 머물러요 떠나면 안돼요 그리움 두고 머나먼 길 그대 무지개를 찾아올 순 ...
# ...                                                 ...
# 4319  운무를 품에 안고 사랑 찾는 무룡산아 산딸기 머루 다래 따다주던 그 손길 앵두같은 ...
# 4320  당신이 주신 가락지 먼 길을 떠나는 당신 하염없는 눈물로 한 짝을 떼어 당신 손에 ...
# 4321  힘이 들 때면 너를 생각해 하루 중에 바쁜 시간도 널 위해 참는 거야 정말 미안해 ...
# 4322  여기에 당신의 모습이 보인다 가슴에 기대어 수줍던 그모습이 세월은 흘러서 당신은 떠...
# 4323  초여름 산들바람 고운볼에스칠때 검은머리 금비녀에 다홍치마 어여뻐라 꽃가마에 미소짓는...
#
# [4324 rows x 5 columns]

# %%
df1 = df[df['lyric']=='가사없음'].index
df = df.drop(df1)
df # '가사없음' 45개
# Out:
#                            _id       genre              title singer  \
# 0     600fe17de8010db47d0367c1         발라드  이 소설의 끝을 다시 써보려 해    한동근
# 1     600fe17de8010db47d0367c2  발라드, 국내드라마           걱정말아요 그대     이적
# 2     600fe17de8010db47d0367c3         발라드            또 다시 사랑    임창정
# 3     600fe17de8010db47d0367c4         발라드       바람이 불었으면 좋겠어   길구봉구
# 4     600fe17de8010db47d0367c5  발라드, 국내드라마                 소녀     오혁
# ...                        ...         ...                ...    ...
# 4319  6010c41d24b299478c39062b        성인가요              울산아리랑    오은정
# 4320  6010c41d24b299478c39062c        성인가요                가락지    황진희
# 4321  6010c41d24b299478c39062e        성인가요           존재의 이유 Ⅱ    김종환
# 4322  6010c41d24b299478c39062f        성인가요             당신은 몰라     최헌
# 4323  6010c41d24b299478c390630        성인가요              백치아다다    문주란
#
#                                                   lyric
# 0     시계가 반대로 돌아가고 있어   속 영화가 되감아지고 있어 내렸던 빗물이 올라가고 ...
# 1     그대여 아무 걱정 하지 말아요 우리 함께 노래 합시다 그대 아픈 기억들 모두 그대여...
# 2     아픔이 좀 더 작아질까 의미 없는 만남을 하다가 어느 날 그대가 흘린 눈물 왠지 나...
# 3     웃는 모습이 너무 아름다운 그런 너를 기억하면서 괜찮아 넌 잘할거라 말하던 또 그런...
# 4     내 곁에만 머물러요 떠나면 안돼요 그리움 두고 머나먼 길 그대 무지개를 찾아올 순 ...
# ...                                                 ...
# 4319  운무를 품에 안고 사랑 찾는 무룡산아 산딸기 머루 다래 따다주던 그 손길 앵두같은 ...
# 4320  당신이 주신 가락지 먼 길을 떠나는 당신 하염없는 눈물로 한 짝을 떼어 당신 손에 ...
# 4321  힘이 들 때면 너를 생각해 하루 중에 바쁜 시간도 널 위해 참는 거야 정말 미안해 ...
# 4322  여기에 당신의 모습이 보인다 가슴에 기대어 수줍던 그모습이 세월은 흘러서 당신은 떠...
# 4323  초여름 산들바람 고운볼에스칠때 검은머리 금비녀에 다홍치마 어여뻐라 꽃가마에 미소짓는...
#
# [4323 rows x 5 columns]

# %%
df1 = df[df['genre']=='성인가요'].index
df = df.drop(df1)
df # 트로트 제거
# Out:
#                            _id        genre                title singer  \
# 0     600fe17de8010db47d0367c1          발라드    이 소설의 끝을 다시 써보려 해    한동근
# 1     600fe17de8010db47d0367c2   발라드, 국내드라마             걱정말아요 그대     이적
# 2     600fe17de8010db47d0367c3          발라드              또 다시 사랑    임창정
# 3     600fe17de8010db47d0367c4          발라드         바람이 불었으면 좋겠어   길구봉구
# 4     600fe17de8010db47d0367c5   발라드, 국내드라마                   소녀     오혁
# ...                        ...          ...                  ...    ...
# 4038  6010c41d24b299478c3904fa    발라드, 성인가요                   애심    전영록
# 4055  6010c41d24b299478c39050d  성인가요, 국내드라마            애월랑 (愛月浪)    장윤정
# 4067  6010c41d24b299478c39051b  성인가요, 국내드라마               그놈에 사랑    조항조
# 4073  6010c41d24b299478c390521    발라드, 성인가요               아득히 먼곳    이승재
# 4301  6010c41d24b299478c390616    발라드, 성인가요  편지 (With SG워너비-채동하)    장윤정
#
#                                                   lyric
# 0     시계가 반대로 돌아가고 있어   속 영화가 되감아지고 있어 내렸던 빗물이 올라가고 ...
# 1     그대여 아무 걱정 하지 말아요 우리 함께 노래 합시다 그대 아픈 기억들 모두 그대여...
# 2     아픔이 좀 더 작아질까 의미 없는 만남을 하다가 어느 날 그대가 흘린 눈물 왠지 나...
# 3     웃는 모습이 너무 아름다운 그런 너를 기억하면서 괜찮아 넌 잘할거라 말하던 또 그런...
# 4     내 곁에만 머물러요 떠나면 안돼요 그리움 두고 머나먼 길 그대 무지개를 찾아올 순 ...
# ...                                                 ...
# 4038  오늘이 가기 전에 떠나갈 당신이여 이제는 영영 가는 아쉬운 당신이여 바람이 부는 언...
# 4055  사랑이 오네요 설레임 태우고 살랑살랑 여울져 가라고도 못해요 이별이 오네요 그리움 ...
# 4067  넓고 넓은 이 세상에 말도 많고 탈도 많지만 결국 하나 원하는 것 함부로 가질 수 ...
# 4073  찬바람 비껴 불어 이르는 곳에 마음을 두고 온 것도 아니라오 먹구름 흐트러져 휘도는...
# 4301  그대를 생각하면 자꾸만 눈물이 나요 언제나 변함없는 그대 사랑에 난 해줄게 없네요 ...
#
# [3853 rows x 5 columns]

# %%
df.to_csv('all_clean_new.csv', index=False)

# %%
import pandas as pd

df = pd.read_csv('all_clean_new.csv')
df
# Out:
#                            _id        genre                title singer  \
# 0     600fe17de8010db47d0367c1          발라드    이 소설의 끝을 다시 써보려 해    한동근
# 1     600fe17de8010db47d0367c2   발라드, 국내드라마             걱정말아요 그대     이적
# 2     600fe17de8010db47d0367c3          발라드              또 다시 사랑    임창정
# 3     600fe17de8010db47d0367c4          발라드         바람이 불었으면 좋겠어   길구봉구
# 4     600fe17de8010db47d0367c5   발라드, 국내드라마                   소녀     오혁
# ...                        ...          ...                  ...    ...
# 3848  6010c41d24b299478c3904fa    발라드, 성인가요                   애심    전영록
# 3849  6010c41d24b299478c39050d  성인가요, 국내드라마            애월랑 (愛月浪)    장윤정
# 3850  6010c41d24b299478c39051b  성인가요, 국내드라마               그놈에 사랑    조항조
# 3851  6010c41d24b299478c390521    발라드, 성인가요               아득히 먼곳    이승재
# 3852  6010c41d24b299478c390616    발라드, 성인가요  편지 (With SG워너비-채동하)    장윤정
#
#                                                   lyric
# 0     시계가 반대로 돌아가고 있어   속 영화가 되감아지고 있어 내렸던 빗물이 올라가고 ...
# 1     그대여 아무 걱정 하지 말아요 우리 함께 노래 합시다 그대 아픈 기억들 모두 그대여...
# 2     아픔이 좀 더 작아질까 의미 없는 만남을 하다가 어느 날 그대가 흘린 눈물 왠지 나...
# 3     웃는 모습이 너무 아름다운 그런 너를 기억하면서 괜찮아 넌 잘할거라 말하던 또 그런...
# 4     내 곁에만 머물러요 떠나면 안돼요 그리움 두고 머나먼 길 그대 무지개를 찾아올 순 ...
# ...                                                 ...
# 3848  오늘이 가기 전에 떠나갈 당신이여 이제는 영영 가는 아쉬운 당신이여 바람이 부는 언...
# 3849  사랑이 오네요 설레임 태우고 살랑살랑 여울져 가라고도 못해요 이별이 오네요 그리움 ...
# 3850  넓고 넓은 이 세상에 말도 많고 탈도 많지만 결국 하나 원하는 것 함부로 가질 수 ...
# 3851  찬바람 비껴 불어 이르는 곳에 마음을 두고 온 것도 아니라오 먹구름 흐트러져 휘도는...
# 3852  그대를 생각하면 자꾸만 눈물이 나요 언제나 변함없는 그대 사랑에 난 해줄게 없네요 ...
#
# [3853 rows x 5 columns]
